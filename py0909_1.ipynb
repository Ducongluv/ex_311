# %%
# loc[행옵션, 열옵션] : 레이블 인덱스
# iloc[행옵션, 열옵션] : 위치값
# [] : 열 레이블, 표현식(T/F 조건식, 논리식, 슬라이싱, ....)

# %%
import pandas as pd

df = pd.DataFrame({
    '이름': ['김철수', '이영희', '박민수', '최수진', '정우진'],
    '학년': [1, 2, 1, 3, 2],
    '점수': [85, 92, 78, 95, 88]
}, index=['A', 'B', 'C', 'D', 'E'])

print(df)
# Out:
#     이름  학년  점수
# A  김철수   1  85
# B  이영희   2  92
# C  박민수   1  78
# D  최수진   3  95
# E  정우진   2  88
