# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
            "이름" : ["홍길동", "김철수", "이영희"],
            "나이" : [20, 30, 25],
            "점수" : [90, 80, 95]})

# %%
df1.loc[0]
# Out:
# 이름    홍길동
# 나이     20
# 점수     90
# Name: 0, dtype: object
